# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_test = pd.read_csv("../Data/pulsar_data_test.csv", comment="#")
print(df_train.columns)
mean = df_train[" Mean of the integrated profile"]
std = df_train[" Standard deviation of the integrated profile"]
skew = df_train[" Skewness of the integrated profile"]
exc = df_train[" Excess kurtosis of the integrated profile"]

print("1st col size: ",len(df_train.columns[0]))


# 1. Count missing values per column
print("Missing values per column:")
print(df_train.isna().sum())

# 2. Total missing values in the dataset
print("\nTotal missing values in dataset:", df_train.isna().sum().sum())

# 3. Get all train_rows that have *any* missing value
train_rows_with_missing = df_train[df_train.isna().any(axis=1)]
print("\nNumber of train_rows with at least one missing value:", len(rows_with_missing))

# 4. Show first few incomplete train_rows (to inspect)
print("\nExample train_rows with missing values:")
print(train_rows_with_missing.head())

# Remove all train_rows where *any* column has a missing value
df_train_clean = df_train.dropna()

# Check new number of train_rows
print("Original number of train_rows:", len(df_train))
print("Number of train_rows after removing train_rows with missing values:", len(df_train_clean))
# Out:
# Index([' Mean of the integrated profile',
#        ' Standard deviation of the integrated profile',
#        ' Excess kurtosis of the integrated profile',
#        ' Skewness of the integrated profile', ' Mean of the DM-SNR curve',
#        ' Standard deviation of the DM-SNR curve',
#        ' Excess kurtosis of the DM-SNR curve', ' Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')
# 1st col size:  31
# Missing values per column:
#  Mean of the integrated profile                     0
#  Standard deviation of the integrated profile       0
#  Excess kurtosis of the integrated profile       1735
#  Skewness of the integrated profile                 0
#  Mean of the DM-SNR curve                           0
#  Standard deviation of the DM-SNR curve          1178
#  Excess kurtosis of the DM-SNR curve                0
#  Skewness of the DM-SNR curve                     625
# target_class                                        0
# dtype: int64
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_test = pd.read_csv("../Data/pulsar_data_test.csv", comment="#")

# Drop last column
df_test = df_test.iloc[:, :-1]

print(df_test.columns)
mean = df_test[" Mean of the integrated profile"]
std = df_test[" Standard deviation of the integrated profile"]
skew = df_test[" Skewness of the integrated profile"]
exc = df_test[" Excess kurtosis of the integrated profile"]

print("1st col size: ",len(df_test.columns[0]))


# 1. Count missing values per column
print("Missing values per column:")
print(df_test.isna().sum())

# 2. Total missing values in the dataset
print("\nTotal missing values in dataset:", df_test.isna().sum().sum())

# 3. Get all test_rows that have *any* missing value
test_rows_with_missing = df_test[df_test.isna().any(axis=1)]
print("\nNumber of test_rows with at least one missing value:", len(test_rows_with_missing))

# 4. Show first few incomplete test_rows (to inspect)
print("\nExample test_rows with missing values:")
print(test_rows_with_missing.head())

# Remove all test_rows where *any* column has a missing value
df_test_clean = df_test.dropna()

# Check new number of test_rows
print("Original number of test_rows:", len(df_test))
print("Number of test_rows after removing test_rows with missing values:", len(df_test_clean))
# Out:
# Index([' Mean of the integrated profile',
#        ' Standard deviation of the integrated profile',
#        ' Excess kurtosis of the integrated profile',
#        ' Skewness of the integrated profile', ' Mean of the DM-SNR curve',
#        ' Standard deviation of the DM-SNR curve',
#        ' Excess kurtosis of the DM-SNR curve',
#        ' Skewness of the DM-SNR curve'],
#       dtype='object')
# 1st col size:  31
# Missing values per column:
# Mean of the integrated profile                    0
# Standard deviation of the integrated profile      0
# Excess kurtosis of the integrated profile       767
# Skewness of the integrated profile                0
# Mean of the DM-SNR curve                          0
# Standard deviation of the DM-SNR curve          524
# Excess kurtosis of the DM-SNR curve               0
# Skewness of the DM-SNR curve                    244
# dtype: int64
#
# Total missing values in dataset: 1535
#
# ...

# %% [markdown]
# ⚠️ NOTE:
# **You need to perform cross-validation and hyperparameter tuning to improve your model's performance for your FINAL, practical project. Write it down in your to-do list, and remember it, not only for your project, but for any future machine learning tasks you work on.**
